# %% [markdown]
# This will be my sine function.

# %%
import math

def sin_function(x):
    return math.sin(x)

# %% [markdown]
# This will be my cosine function.

# %%
def cos_function(x):
    return math.cos(x)

# %% [markdown]
# This is the cell meant to tabulate sin(x) and cos(x) for a thousand entries.

# %%
x0 = float(0.0)
x1 = float(2.0)

dx = (x1 - x0) / (1000 - 1)

x_vals = []
sin_vals = []
cos_vals = []

x = x0
n = 1000
for i in range(n):
    x_vals.append(x)
    sin_vals.append(sin_function(x))
    cos_vals.append(cos_function(x))
    x += dx

# %% [markdown]
# THis is the code cell meant to run the for loop

# %%
print(f"{'x':>10} {'sin(x)':>15} {'cos(x)':>15}")

for i in range(10):
    print(f"{f_vals[i]:10.6f} {sin_vals[i]:15.8f" {cos_vals[i]:15.8f}}" )
# Out:
#   Cell In[16], line 4
#     print(f"{f_vals[i]:10.6f} {sin_vals[i]:15.8f" {cos_vals[i]:15.8f}}" )
#                                                                   ^
# SyntaxError: invalid decimal literal
